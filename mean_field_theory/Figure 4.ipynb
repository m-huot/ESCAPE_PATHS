# %% [markdown]
# # Time taken to adapt to a cocktail

# %%
from scipy.stats import pearsonr, spearmanr
spearmanr([1,2],[1,2])
# Out:
# SignificanceResult(statistic=0.9999999999999999, pvalue=nan)

# %%
import os
import sys
import torch
from itertools import product
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text
from matplotlib.markers import MarkerStyle
from matplotlib.lines import Line2D
from scipy.stats import pearsonr
from matplotlib import cm
from adjustText import adjust_text
import matplotlib as mpl
import re
import math

from tqdm import tqdm

main_path = "../"

sys.path.append(main_path + "PGM/source/")
sys.path.append(main_path + "PGM/utilities/")
import utilities, Proteins_utils, sequence_logo, plots_utils

os.chdir('../covid')
from global_variables import *
from utils_evaluate_seq import *
os.chdir('../mean_field_theory')

from utils_mean_field import *
from utils_rbm_mean_field import *
# Out:
# e:\ESCAPE_PATHS\mean_field_theory\../PGM/source\numba_utilities.py:1124: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float32, 2, 'F', False, aligned=True), Array(float32, 2, 'A', False, aligned=True))
#   dmean_v_dw = np.dot(s1.T, V)
# e:\ESCAPE_PATHS\mean_field_theory\../PGM/source\numba_utilities.py:961: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float32, 1, 'A', False, aligned=True), Array(float32, 2, 'A', False, aligned=True))
#   mean_V = np.dot(weights, V) / sum_weights
# Loaded 29 KD vectors
# C:\Users\maria\AppData\Roaming\Python\Python312\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
PROT_INIT = Proteins_utils.load_FASTA("../covid/exp_data/wt_omicron.fasta")[0]
PROT_INIT = PROT_INIT[BEGIN:-END]

# %%
L=PROT_INIT.shape[0]
Q = 20

# %%
ab_names= list(ESCAPE_VECTORS.keys())
ab_focused = ["REGN10933", "REGN10987",'LY-CoV555','LY-CoV016']
indexes_abs = [ab_names.index(ab) for ab in ab_focused]
ab_names
# Out:
# ['COV2-2050',
#  'COV2-2082',
#  'COV2-2094',
#  'COV2-2096',
#  'COV2-2130',
#  'COV2-2165',
#  'COV2-2196',
#  'COV2-2479',
#  'COV2-2499',
#  'COV2-2677',
#  'COV2-2832',
#  'CR3022',
#  'LY-CoV016',
#  'LY-CoV555',
#  'REGN10933',
#  'REGN10987',
#  'S2D106',
#  'S2E12',
#  'S2H13',
#  'S2H14',
#  'S2H58',
#  'S2H97',
#  'S2X16',
#  'S2X227',
#  'S2X259',
#  'S2X35',
#  'S2X58',
#  'S304',
#  'S309']

# %%
os.listdir('results_scripts')
# Out:
# ['all_cocktails', 'cocktails_beta', 'covid_D_20', 'covid_D_20_ba1', 'lattice']

# %% [markdown]
# # Order params

# %%
style_dict = {
    "REGN10933": {"color": "red", "linestyle": "--"},
    "REGN10987": {"color": "orange", "linestyle": "--"},
    "LY-CoV555": {"color": "deepskyblue", "linestyle": "-"},
    "LY-CoV016": {"color": "darkblue", "linestyle": "-"},
    "COV2-2196": {"color": "green", "linestyle": "-"},
}

dir = 'results_scripts/cocktails_beta'
BETA_AB = 1
D = 1

def extract_parameters(path):
    beta_ab_match = re.search(r'beta_ab_(\d+(?:\.\d+)?)', path)
    D_match = re.search(r'D_(\d+)', path)
    ab_parts = path.split('ab_')
    condition = ab_parts[3] if len(ab_parts) > 3 else None
    return {
        "beta_ab": float(beta_ab_match.group(1)) if beta_ab_match else None,
        "D": int(D_match.group(1)) if D_match else None,
        "condition": condition
    }

condition_sets = [
    ["REGN10987", "COV2-2196", "REGN10933_COV2-2196"],
    ["REGN10933_REGN10987"],
]

all_dirs = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]

paths = []
labels = []

for condition_set in condition_sets:
    for condition in condition_set:
        for d in all_dirs:
            params = extract_parameters(d)
            if (
                params["beta_ab"] == BETA_AB and
                params["D"] == D and
                params["condition"] == condition
            ):
                paths.append(d)
                labels.append(condition)
                break 

mpl.rcParams.update({
    "text.usetex": True,
    "axes.titlesize": 12,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "legend.fontsize": 10,
    "figure.titlesize": 14
})

n_paths = len(labels)
n_cols = 4
n_rows = math.ceil(n_paths / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4.8 * n_cols, 3.5 * n_rows))
axes = axes.flatten()

for i, condition in enumerate(labels):
    abs_involved = condition.split("_") if "_" in condition else [condition]

    mopt = np.exp(np.load(os.path.join(dir, paths[i], "mopt.npy"))[:, :])

    ax = axes[i]

    for ab in abs_involved:
        ab_idx = ab_names.index(ab)
        ax.plot(mopt[:, ab_idx],
                label=ab,
                color=style_dict[ab]["color"],
                linestyle=style_dict[ab]["linestyle"],
                linewidth=1.5)

 
    indices = [ab_names.index(ab) for ab in abs_involved]
    

    all_escaped = np.all(mopt[:, indices] < 0.5, axis=1)
    
    cross_idx = np.argmax(all_escaped) if np.any(all_escaped) else None
    
    if cross_idx is not None:
        ax.axvline(cross_idx, color="black", linestyle=":", linewidth=1.2, label=r"All Abs $>50\%$ escape")

    ax.set_title(condition.replace("_", " + "), pad=10)
    ax.set_xlabel(r"Step", fontsize=14)
    ax.set_ylabel(r"Binding $\sim e^{L\, \gamma_{\mathrm{opt}}}$", fontsize=14)
    ax.set_ylim(0, 1.02)
    ax.set_xlim(left=0)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(True, which='major', linestyle=':', linewidth=0.5)
    ax.legend(frameon=False, loc='upper right')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(pad=1.2)
plt.subplots_adjust(hspace=0.35, wspace=0.3)
plt.show()

# %%
mpl.rcParams.update({
    "text.usetex": True,
    "axes.titlesize": 24,
    "xtick.labelsize": 24,
    "ytick.labelsize": 24,
    "legend.fontsize": 24,
    "figure.titlesize": 20
})

n_paths = len(labels)
n_cols = 4
n_rows = math.ceil(n_paths / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4.2 * n_cols, 4 * n_rows))
axes = axes.flatten()

for i, condition in enumerate(labels):
    abs_involved = condition.split("_") if "_" in condition else [condition]

    mopt = np.exp(np.load(os.path.join(dir, paths[i], "mopt.npy"))[:, :] )

    ax = axes[i]

    indices = [ab_names.index(ab) for ab in abs_involved]
    fitness = np.prod(1 - mopt[:, indices], axis=1)

    ax.plot(fitness,
            color="black",
            linestyle="-",
            linewidth=2)


    cross_idx = np.argmax(fitness > 0.5) if np.any(fitness > 0.5) else None
    if cross_idx is not None:
        fitness_val = fitness[cross_idx]
        ax.axvline(cross_idx, ymax=fitness_val, color="black", linestyle=":", linewidth=1.2)
        ax.axhline(fitness_val, xmax=cross_idx / len(fitness), color="black", linestyle=":", linewidth=1.2)
        ax.plot(cross_idx, fitness_val, marker='o', color='black', markersize=4)


    ax.set_title(condition.replace("_", " + "), pad=10)
    ax.set_xlabel(r"Step", fontsize=25)
    ax.set_ylabel(r"$P_{escape}$", fontsize=25)
    ax.set_ylim(0, 1.02)
    ax.set_xlim(left=0)

    ax.set_xticks(np.arange(0, len(fitness), 3))

    ax.plot([], [], color="black", linestyle=":", linewidth=1.2, label=r"$\geq 50\%$ escape")

    ax.legend(frameon=False, loc='upper right')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(pad=1.2)
plt.subplots_adjust(hspace=0.35, wspace=0.3)
plt.show()

# %% [markdown]
# # RBM energy at escape step

# %%
PROT_INIT = Proteins_utils.load_FASTA("../covid/exp_data/wt_omicron.fasta")[0]
PROT_INIT = PROT_INIT[BEGIN:-END]


L = PROT_INIT.shape[0]
Q = 20


gamma_f_list = create_gamma_functions(
    torch.tensor(RBM.hlayer.gamma_plus),
    torch.tensor(RBM.hlayer.gamma_minus),
    torch.tensor(RBM.hlayer.theta_plus),
    torch.tensor(RBM.hlayer.theta_minus),
    L,
)


selection_coeff_list = []
selection_coeff_list_gamma_only = []
selection_coeff_list_gamma_only.extend(create_ab_functions(n_ab=29, beta_ab=0, L=L))
selection_coeff_list_gamma_only.extend(gamma_f_list)

selection_coeff_list.extend(create_ab_functions(n_ab=29, beta_ab=1, L=L))
selection_coeff_list.extend(gamma_f_list)


ab_names = list(ESCAPE_VECTORS.keys())
wab = np.zeros((L, Q, len(ab_names)))
for idx, ab in enumerate(ab_names):
    w_ab = ESCAPE_VECTORS[ab].reshape(L, Q)  # "no bias"
    wab[:, :, idx] = w_ab

for i in range(len(ab_names)):
    if np.any(wab[:, :, i] > 0):
        raise ValueError(f"Escape vector {ab_names[i]} has positive coeffs")

wgamma = np.transpose(RBM.weights[:, :, :], (1, 2, 0))
g = RBM.vlayer.fields


w_components = []
w_components.append(wab)
w_components.append(wgamma)
w = np.concatenate(w_components, axis=-1)

def get_zeta(mopt, selection_coeff_list_gamma_only):
    """
    returns potential of gamma and ab
    """
    zeta_values_gamma_only = []

    for j in range(mopt.shape[0]):

        zeta_values_gamma_only.append(
            Zeta(torch.tensor(mopt[j]), selection_coeff_list_gamma_only, L)
            .detach()
            .numpy()
        )
    zeta_values_gamma_only = np.array(zeta_values_gamma_only)
    return zeta_values_gamma_only


def get_phi(qopt, q_c):
    phi_values = Phi_cont(torch.tensor(qopt), q_c, L).detach().numpy()
    return phi_values


def get_field(path_proba):
    path_proba = np.moveaxis(path_proba, 0, -1)
    field = np.empty(path_proba.shape[0]) 

    for t in range(path_proba.shape[0]):  
        field[t] = np.sum(path_proba[t] * g.T)  

    return -field

# %% [markdown]
# # all cocktails

# %%
dir='results_scripts/all_cocktails'
all_dirs = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]

all_paths = []
labels = []


for d in all_dirs:
    params = extract_parameters(d)
    if (
        params["beta_ab"] == BETA_AB and
        params["D"] == D 
    ):
        all_paths.append(d)
        labels.append(condition)


def get_escape_step(filepath, ab_indices, L):
    """Compute escape step where fitness crosses 0.5"""
    mopt = np.exp(np.load(filepath+'/mopt.npy')[:, :])
    fitness = np.prod(1 - mopt[:, ab_indices], axis=1)
    escape_step = np.argmax(fitness > 0.5) if np.any(fitness > 0.5) else len(fitness)
    return escape_step

def compute_delta_escape_steps(all_dir, ab_names, L):
    results = {}

    for fname in os.listdir(all_dir):
        if not fname.startswith("mean_f_free_ab_beta_ab_1_D_1_ab_"):
            continue
     

        ab_part = fname.split("ab_")[3]
        abs_involved = ab_part.split("_")
        abs_involved = [ab for ab in abs_involved if ab in ab_names]

        if len(abs_involved) < 2:
            continue  

        cocktail_path = os.path.join(dir, fname)
        cocktail_indices = [ab_names.index(ab) for ab in abs_involved]
        cocktail_escape = get_escape_step(cocktail_path, cocktail_indices, L)

        single_escapes = []
        for ab in abs_involved:
            ab_fname = f"mean_f_free_ab_beta_ab_1_D_1_ab_{ab}"
            ab_path = os.path.join(all_dir, ab_fname)
            if not os.path.exists(ab_path):
                print(f"Missing file for {ab}, skipping cocktail {fname}")
                break
            ab_index = [ab_names.index(ab)]
            ab_escape = get_escape_step(ab_path, ab_index, L)
            single_escapes.append(ab_escape)
        else:
            delta = cocktail_escape - max(single_escapes)
            results[fname] = {
                "cocktail_step": cocktail_escape,
                "individual_steps": dict(zip(abs_involved, single_escapes)),
                "delta_escape_step": delta
            }

    return results
delta_steps = compute_delta_escape_steps(dir, ab_names, L)
delta_steps
# Out:
# {'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2082': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2082': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2094': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2094': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2096': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2096': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2130': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2130': 4},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2165': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2165': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2196': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2196': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2499': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2050': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2094': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2094': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2096': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2096': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2130': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2130': 4},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2165': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2165': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2196': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2196': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2499': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2082': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2096': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2096': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2130': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2130': 4},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2165': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2165': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2196': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2196': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2499': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2094': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2130': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2130': 4},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2165': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2165': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2196': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2196': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2499': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2096': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2165': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'COV2-2165': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2196': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2130': 4, 'COV2-2196': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'COV2-2499': 5},
#   'delta_escape_step': 6},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_LY-CoV016': {'cocktail_step': 4,
#   'individual_steps': {'COV2-2130': 4, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_LY-CoV555': {'cocktail_step': 9,
#   'individual_steps': {'COV2-2130': 4, 'LY-CoV555': 3},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_REGN10933': {'cocktail_step': 9,
#   'individual_steps': {'COV2-2130': 4, 'REGN10933': 3},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_REGN10987': {'cocktail_step': 3,
#   'individual_steps': {'COV2-2130': 4, 'REGN10987': 2},
#   'delta_escape_step': -1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S2D106': 10},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2E12': {'cocktail_step': 6,
#   'individual_steps': {'COV2-2130': 4, 'S2E12': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H13': {'cocktail_step': 4,
#   'individual_steps': {'COV2-2130': 4, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H14': {'cocktail_step': 6,
#   'individual_steps': {'COV2-2130': 4, 'S2H14': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S2H58': 5},
#   'delta_escape_step': 6},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X16': {'cocktail_step': 6,
#   'individual_steps': {'COV2-2130': 4, 'S2X16': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S2X227': 7},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S2X35': 8},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X58': {'cocktail_step': 3,
#   'individual_steps': {'COV2-2130': 4, 'S2X58': 1},
#   'delta_escape_step': -1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S304': {'cocktail_step': 8,
#   'individual_steps': {'COV2-2130': 4, 'S304': 2},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2130': 4, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2196': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'COV2-2196': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'COV2-2499': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2165': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2479': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'COV2-2479': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2499': {'cocktail_step': 9,
#   'individual_steps': {'COV2-2196': 2, 'COV2-2499': 5},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_LY-CoV016': {'cocktail_step': 2,
#   'individual_steps': {'COV2-2196': 2, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_LY-CoV555': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2196': 2, 'LY-CoV555': 3},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_REGN10933': {'cocktail_step': 3,
#   'individual_steps': {'COV2-2196': 2, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_REGN10987': {'cocktail_step': 4,
#   'individual_steps': {'COV2-2196': 2, 'REGN10987': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'S2D106': 10},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2E12': {'cocktail_step': 2,
#   'individual_steps': {'COV2-2196': 2, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H13': {'cocktail_step': 5,
#   'individual_steps': {'COV2-2196': 2, 'S2H13': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H14': {'cocktail_step': 4,
#   'individual_steps': {'COV2-2196': 2, 'S2H14': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H58': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2196': 2, 'S2H58': 5},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X16': {'cocktail_step': 2,
#   'individual_steps': {'COV2-2196': 2, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X227': {'cocktail_step': 10,
#   'individual_steps': {'COV2-2196': 2, 'S2X227': 7},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X35': {'cocktail_step': 10,
#   'individual_steps': {'COV2-2196': 2, 'S2X35': 8},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X58': {'cocktail_step': 4,
#   'individual_steps': {'COV2-2196': 2, 'S2X58': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S304': {'cocktail_step': 5,
#   'individual_steps': {'COV2-2196': 2, 'S304': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2196': 2, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_COV2-2499': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'COV2-2499': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2479': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_COV2-2677': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'COV2-2677': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_LY-CoV016': {'cocktail_step': 5,
#   'individual_steps': {'COV2-2499': 5, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'LY-CoV555': 3},
#   'delta_escape_step': 6},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'REGN10933': 3},
#   'delta_escape_step': 6},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_REGN10987': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2499': 5, 'REGN10987': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S2D106': 10},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2E12': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2499': 5, 'S2E12': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H13': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2499': 5, 'S2H13': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H14': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2499': 5, 'S2H14': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S2H58': 5},
#   'delta_escape_step': 6},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X16': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2499': 5, 'S2X16': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S2X227': 7},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S2X35': 8},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X58': {'cocktail_step': 7,
#   'individual_steps': {'COV2-2499': 5, 'S2X58': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S304': {'cocktail_step': 10,
#   'individual_steps': {'COV2-2499': 5, 'S304': 2},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2499': 5, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_COV2-2832': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'COV2-2832': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2677': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_CR3022': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'CR3022': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S304': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S309': {'cocktail_step': 11,
#   'individual_steps': {'COV2-2832': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_LY-CoV016': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'LY-CoV016': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_LY-CoV555': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_REGN10933': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_REGN10987': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2H14': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S304': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S309': {'cocktail_step': 11,
#   'individual_steps': {'CR3022': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_LY-CoV555': {'cocktail_step': 3,
#   'individual_steps': {'LY-CoV016': 1, 'LY-CoV555': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_REGN10933': {'cocktail_step': 3,
#   'individual_steps': {'LY-CoV016': 1, 'REGN10933': 3},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_REGN10987': {'cocktail_step': 2,
#   'individual_steps': {'LY-CoV016': 1, 'REGN10987': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2D106': {'cocktail_step': 10,
#   'individual_steps': {'LY-CoV016': 1, 'S2D106': 10},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2E12': {'cocktail_step': 2,
#   'individual_steps': {'LY-CoV016': 1, 'S2E12': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H13': {'cocktail_step': 3,
#   'individual_steps': {'LY-CoV016': 1, 'S2H13': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H14': {'cocktail_step': 3,
#   'individual_steps': {'LY-CoV016': 1, 'S2H14': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H58': {'cocktail_step': 5,
#   'individual_steps': {'LY-CoV016': 1, 'S2H58': 5},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV016': 1, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X16': {'cocktail_step': 2,
#   'individual_steps': {'LY-CoV016': 1, 'S2X16': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X227': {'cocktail_step': 7,
#   'individual_steps': {'LY-CoV016': 1, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV016': 1, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X35': {'cocktail_step': 8,
#   'individual_steps': {'LY-CoV016': 1, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X58': {'cocktail_step': 2,
#   'individual_steps': {'LY-CoV016': 1, 'S2X58': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S304': {'cocktail_step': 3,
#   'individual_steps': {'LY-CoV016': 1, 'S304': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S309': {'cocktail_step': 9,
#   'individual_steps': {'LY-CoV016': 1, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_REGN10933': {'cocktail_step': 8,
#   'individual_steps': {'LY-CoV555': 3, 'REGN10933': 3},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_REGN10987': {'cocktail_step': 6,
#   'individual_steps': {'LY-CoV555': 3, 'REGN10987': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV555': 3, 'S2D106': 10},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2E12': {'cocktail_step': 6,
#   'individual_steps': {'LY-CoV555': 3, 'S2E12': 1},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H13': {'cocktail_step': 6,
#   'individual_steps': {'LY-CoV555': 3, 'S2H13': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H14': {'cocktail_step': 6,
#   'individual_steps': {'LY-CoV555': 3, 'S2H14': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H58': {'cocktail_step': 10,
#   'individual_steps': {'LY-CoV555': 3, 'S2H58': 5},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV555': 3, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X16': {'cocktail_step': 3,
#   'individual_steps': {'LY-CoV555': 3, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV555': 3, 'S2X227': 7},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV555': 3, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV555': 3, 'S2X35': 8},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X58': {'cocktail_step': 5,
#   'individual_steps': {'LY-CoV555': 3, 'S2X58': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S304': {'cocktail_step': 8,
#   'individual_steps': {'LY-CoV555': 3, 'S304': 2},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S309': {'cocktail_step': 11,
#   'individual_steps': {'LY-CoV555': 3, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_REGN10987': {'cocktail_step': 5,
#   'individual_steps': {'REGN10933': 3, 'REGN10987': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'REGN10933': 3, 'S2D106': 10},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2E12': {'cocktail_step': 3,
#   'individual_steps': {'REGN10933': 3, 'S2E12': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H13': {'cocktail_step': 6,
#   'individual_steps': {'REGN10933': 3, 'S2H13': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H14': {'cocktail_step': 5,
#   'individual_steps': {'REGN10933': 3, 'S2H14': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H58': {'cocktail_step': 7,
#   'individual_steps': {'REGN10933': 3, 'S2H58': 5},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'REGN10933': 3, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X16': {'cocktail_step': 3,
#   'individual_steps': {'REGN10933': 3, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'REGN10933': 3, 'S2X227': 7},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'REGN10933': 3, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'REGN10933': 3, 'S2X35': 8},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X58': {'cocktail_step': 5,
#   'individual_steps': {'REGN10933': 3, 'S2X58': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S304': {'cocktail_step': 7,
#   'individual_steps': {'REGN10933': 3, 'S304': 2},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S309': {'cocktail_step': 11,
#   'individual_steps': {'REGN10933': 3, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2D106': {'cocktail_step': 11,
#   'individual_steps': {'REGN10987': 2, 'S2D106': 10},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2E12': {'cocktail_step': 3,
#   'individual_steps': {'REGN10987': 2, 'S2E12': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H13': {'cocktail_step': 2,
#   'individual_steps': {'REGN10987': 2, 'S2H13': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H14': {'cocktail_step': 4,
#   'individual_steps': {'REGN10987': 2, 'S2H14': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H58': {'cocktail_step': 8,
#   'individual_steps': {'REGN10987': 2, 'S2H58': 5},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'REGN10987': 2, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X16': {'cocktail_step': 3,
#   'individual_steps': {'REGN10987': 2, 'S2X16': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X227': {'cocktail_step': 8,
#   'individual_steps': {'REGN10987': 2, 'S2X227': 7},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'REGN10987': 2, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X35': {'cocktail_step': 9,
#   'individual_steps': {'REGN10987': 2, 'S2X35': 8},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X58': {'cocktail_step': 2,
#   'individual_steps': {'REGN10987': 2, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S304': {'cocktail_step': 5,
#   'individual_steps': {'REGN10987': 2, 'S304': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S309': {'cocktail_step': 11,
#   'individual_steps': {'REGN10987': 2, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2E12': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2E12': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H13': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2H13': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H14': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2H14': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H58': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2H58': 5},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2X16': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2X227': 7},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2X35': 8},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S2X58': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S304': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S304': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2D106': 10, 'S309': 9},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H13': {'cocktail_step': 4,
#   'individual_steps': {'S2E12': 1, 'S2H13': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H14': {'cocktail_step': 3,
#   'individual_steps': {'S2E12': 1, 'S2H14': 2},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H58': {'cocktail_step': 6,
#   'individual_steps': {'S2E12': 1, 'S2H58': 5},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'S2E12': 1, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X16': {'cocktail_step': 2,
#   'individual_steps': {'S2E12': 1, 'S2X16': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X227': {'cocktail_step': 9,
#   'individual_steps': {'S2E12': 1, 'S2X227': 7},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2E12': 1, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X35': {'cocktail_step': 9,
#   'individual_steps': {'S2E12': 1, 'S2X35': 8},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X58': {'cocktail_step': 3,
#   'individual_steps': {'S2E12': 1, 'S2X58': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S304': {'cocktail_step': 4,
#   'individual_steps': {'S2E12': 1, 'S304': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2E12': 1, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2H14': {'cocktail_step': 4,
#   'individual_steps': {'S2H13': 2, 'S2H14': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2H58': {'cocktail_step': 7,
#   'individual_steps': {'S2H13': 2, 'S2H58': 5},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'S2H13': 2, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X16': {'cocktail_step': 4,
#   'individual_steps': {'S2H13': 2, 'S2X16': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X227': {'cocktail_step': 9,
#   'individual_steps': {'S2H13': 2, 'S2X227': 7},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2H13': 2, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X35': {'cocktail_step': 10,
#   'individual_steps': {'S2H13': 2, 'S2X35': 8},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X58': {'cocktail_step': 2,
#   'individual_steps': {'S2H13': 2, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S304': {'cocktail_step': 5,
#   'individual_steps': {'S2H13': 2, 'S304': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2H13': 2, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2H58': {'cocktail_step': 8,
#   'individual_steps': {'S2H14': 2, 'S2H58': 5},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'S2H14': 2, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X16': {'cocktail_step': 3,
#   'individual_steps': {'S2H14': 2, 'S2X16': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X227': {'cocktail_step': 9,
#   'individual_steps': {'S2H14': 2, 'S2X227': 7},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2H14': 2, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X35': {'cocktail_step': 9,
#   'individual_steps': {'S2H14': 2, 'S2X35': 8},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X58': {'cocktail_step': 3,
#   'individual_steps': {'S2H14': 2, 'S2X58': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S304': {'cocktail_step': 5,
#   'individual_steps': {'S2H14': 2, 'S304': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2H14': 2, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2H97': {'cocktail_step': 11,
#   'individual_steps': {'S2H58': 5, 'S2H97': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X16': {'cocktail_step': 6,
#   'individual_steps': {'S2H58': 5, 'S2X16': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'S2H58': 5, 'S2X227': 7},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2H58': 5, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'S2H58': 5, 'S2X35': 8},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X58': {'cocktail_step': 8,
#   'individual_steps': {'S2H58': 5, 'S2X58': 1},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S304': {'cocktail_step': 10,
#   'individual_steps': {'S2H58': 5, 'S304': 2},
#   'delta_escape_step': 5},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2H58': 5, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X16': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S2X16': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X227': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S2X227': 7},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S304': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2H97': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X227': {'cocktail_step': 9,
#   'individual_steps': {'S2X16': 1, 'S2X227': 7},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2X16': 1, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X35': {'cocktail_step': 9,
#   'individual_steps': {'S2X16': 1, 'S2X35': 8},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X58': {'cocktail_step': 3,
#   'individual_steps': {'S2X16': 1, 'S2X58': 1},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S304': {'cocktail_step': 4,
#   'individual_steps': {'S2X16': 1, 'S304': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2X16': 1, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S2X259': {'cocktail_step': 11,
#   'individual_steps': {'S2X227': 7, 'S2X259': 11},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'S2X227': 7, 'S2X35': 8},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S2X58': {'cocktail_step': 8,
#   'individual_steps': {'S2X227': 7, 'S2X58': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S304': {'cocktail_step': 11,
#   'individual_steps': {'S2X227': 7, 'S304': 2},
#   'delta_escape_step': 4},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2X227': 7, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S2X35': {'cocktail_step': 11,
#   'individual_steps': {'S2X259': 11, 'S2X35': 8},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S2X58': {'cocktail_step': 11,
#   'individual_steps': {'S2X259': 11, 'S2X58': 1},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S304': {'cocktail_step': 11,
#   'individual_steps': {'S2X259': 11, 'S304': 2},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2X259': 11, 'S309': 9},
#   'delta_escape_step': 0},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X35_S2X58': {'cocktail_step': 9,
#   'individual_steps': {'S2X35': 8, 'S2X58': 1},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X35_S304': {'cocktail_step': 11,
#   'individual_steps': {'S2X35': 8, 'S304': 2},
#   'delta_escape_step': 3},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X35_S309': {'cocktail_step': 11,
#   'individual_steps': {'S2X35': 8, 'S309': 9},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X58_S304': {'cocktail_step': 4,
#   'individual_steps': {'S2X58': 1, 'S304': 2},
#   'delta_escape_step': 2},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X58_S309': {'cocktail_step': 10,
#   'individual_steps': {'S2X58': 1, 'S309': 9},
#   'delta_escape_step': 1},
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S304_S309': {'cocktail_step': 11,
#   'individual_steps': {'S304': 2, 'S309': 9},
#   'delta_escape_step': 2}}

# %% [markdown]
# ## Delta escape cocktail vs single ab, compared to Cov weighted by MSA

# %%
msa_seqs=Proteins_utils.load_FASTA('../covid/RBM_artif_seq.fasta')
msa_seqs.shape
# Out:
# (1000, 178)

# %%
escapes = np.array([get_log_bindings(msa_seqs[i]) for i in range(msa_seqs.shape[0])])
escapes.shape
# Out:
# (1000, 29)

# %%
ab_class_df=pd.read_csv('../covid/exp_data/bloom_ab_classification/ab_classification.csv')

class_mapping = ab_class_df.set_index('condition')['condition_subtype'].to_dict()
class_mapping
# Out:
# {'COV2-2196': 'class 1',
#  'COV2-2130': 'class 3',
#  'COV2-2955': 'class 2',
#  'CR3022': 'class 4',
#  'COV2-2677': 'class 4',
#  'COV2-2082': 'class 4',
#  'COV2-2094': 'class 4',
#  'COV2-2165': 'class 1',
#  'COV2-2832': 'class 1',
#  'COV2-2479': 'class 2',
#  'COV2-2050': 'class 2',
#  'COV2-2096': 'class 2',
#  'COV2-2499': 'class 3',
#  'C002': 'class 2',
#  'C105': 'class 1',
#  'C110': 'class 3',
#  'C121': 'class 2',
#  'C135': 'class 3',
#  'C144': 'class 2',
#  'LY-CoV555': 'class 2',
#  'REGN10933': 'class 1',
#  'REGN10987': 'class 3',
#  'LY-CoV016': 'class 1',
#  'S309': 'class 3',
#  'S2H97': 'class 4',
#  'S304': 'class 4',
#  'S2X35': 'class 4',
#  'S2E12': 'class 1',
#  'S2X16': 'class 2',
#  'S2H58': 'class 2',
#  'S2H13': 'class 2',
#  'S2D106': 'class 2',
#  'S2X58': 'class 2',
#  'S2H14': 'class 1',
#  'S2X227': 'class 3',
#  'S2X259': 'class 4'}

# %%
def covariance(x, y):
    """Compute sample covariance (same normalization as np.cov with bias=False)."""
    x_centered = x - np.mean(x)
    y_centered = y - np.mean(y)
    return np.dot(x_centered, y_centered) / (len(x) - 1)

covs = []
deltas = []
pair_labels = []

for cocktail_name, vals in delta_steps.items():
    
    abs_involved = list(vals['individual_steps'].keys())

    if len(abs_involved) != 2:
        continue

    ab1 = abs_involved[0]
    ab2 = abs_involved[1]

    step1 = vals['individual_steps'][ab1]
    step2 = vals['individual_steps'][ab2]

    if step1 >= 10 or step2 >= 10:
        continue

    idx1 = ab_names.index(ab1)
    idx2 = ab_names.index(ab2)

    x = escapes[:, idx1]
    y = escapes[:, idx2]

    cov_value = covariance(x, y)
    
    best_single_step = max(step1, step2)
    
    cocktail_step = vals['cocktail_step'] 
    
    delta = cocktail_step - best_single_step

    covs.append(cov_value)
    deltas.append(delta)
    pair_labels.append(f"{ab1}+{ab2}")

fig, ax = plt.subplots(figsize=(5, 3), dpi=300)

cmap = cm.get_cmap('coolwarm')

if len(covs) > 0:
    cov_arr = np.array(covs)
    norm_covs = (cov_arr - np.min(cov_arr)) / (np.max(cov_arr) - np.min(cov_arr) + 1e-12)
    colors = cmap(norm_covs)
else:
    colors = 'blue'

ax.scatter(covs, deltas, color=colors, s=50, edgecolor='black', linewidth=0.5)


ax.set_xlabel("Covariance between Pair", fontsize=15)
ax.set_ylabel(r"$\Delta$ Escape Step", fontsize=15)
ax.grid(True, linestyle=':', linewidth=0.5)

if len(covs) > 1:
    r, pval = spearmanr(covs, deltas)
    stat_text = fr"$Spearman r = {r:.2f}$" + "\n" + fr"$p = {pval:.3g}$"
    
    ax.text(0.75, 0.95, stat_text, transform=ax.transAxes,
            fontsize=11, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_11644\2947112892.py:47: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('coolwarm')

# %%
def covariance(x, y):
    x_centered = x - np.mean(x)
    y_centered = y - np.mean(y)
    return np.dot(x_centered, y_centered) / (len(x) - 1)



covs = []
deltas = []
pair_labels = []
pair_classes = [] 
ab_pairs = []     

for cocktail_name, vals in delta_steps.items():
    abs_involved = list(vals['individual_steps'].keys())

    if len(abs_involved) != 2:
        continue

    ab1, ab2 = abs_involved[0], abs_involved[1]
    step1 = vals['individual_steps'][ab1]
    step2 = vals['individual_steps'][ab2]

    if step1 >= 10 or step2 >= 10:
        continue

    idx1 = ab_names.index(ab1)
    idx2 = ab_names.index(ab2)
    cov_value = covariance(escapes[:, idx1], escapes[:, idx2])
    
    best_single_step = max(step1, step2)
    cocktail_step = vals['cocktail_step'] 
    delta = cocktail_step - best_single_step

    covs.append(cov_value)
    deltas.append(delta)
    pair_labels.append(f"{ab1}-{ab2}")
    ab_pairs.append((ab1, ab2))
    
    c1 = class_mapping.get(ab1, 'Unknown')
    c2 = class_mapping.get(ab2, 'Unknown')
    pair_classes.append((c1, c2))

covs = np.array(covs)
deltas = np.array(deltas)
pair_labels = np.array(pair_labels)
pair_classes = np.array(pair_classes, dtype=object)

unique_classes = sorted(list(set([c for p in pair_classes for c in p])))
n_classes = len(unique_classes)

if n_classes <= 10:
    cmap_obj = cm.get_cmap('tab10')
    class_colors = [cmap_obj(i) for i in range(n_classes)]

if n_classes > 0:
    cmap_obj = cm.get_cmap('tab10')
    class_colors = cmap_obj(np.linspace(0, 1, n_classes))
else:
    class_colors = []
color_map = dict(zip(unique_classes, class_colors))


sorted_indices = np.argsort(covs)
bottom_5_idx = sorted_indices[:3]
top_5_idx = sorted_indices[-3:]

annotate_indices = np.concatenate([bottom_5_idx, top_5_idx])

fig, ax = plt.subplots(figsize=(7, 4.5), dpi=300)

ax.scatter(covs, deltas, color='silver', s=50, alpha=0.6, label='_nolegend_')

texts = []
for idx in annotate_indices:
    x = covs[idx]
    y = deltas[idx]
    c1_name, c2_name = pair_classes[idx]
    col1 = color_map[c1_name]
    col2 = color_map[c2_name]
    
    ax.scatter(x, y, color=col1, s=120, marker=MarkerStyle('o', fillstyle='left'), zorder=3)
    ax.scatter(x, y, color=col2, s=120, marker=MarkerStyle('o', fillstyle='right'), zorder=3)
    ax.scatter(x, y, facecolors='none', edgecolors='black', s=120, linewidth=0.5, zorder=4)
    
    t = ax.text(x, y, pair_labels[idx], fontsize=9, ha='center', color='black')
    texts.append(t)

adjust_text(texts, ax=ax, 
            arrowprops=dict(arrowstyle="-", color='gray', lw=0.5),
            force_text=(1.2, 1.2),    
            force_points=(0.5, 0.8), 
            expand_points=(1.5, 1.5), 
            lim=1000         
)
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label=cls_name,
           markerfacecolor=col, markersize=10, markeredgecolor='black')
    for cls_name, col in color_map.items()
]
ax.legend(handles=legend_elements, bbox_to_anchor=(.7, 1), loc='upper left', fontsize=10)

ax.set_xlabel("Binding Covariance", fontsize=14)
ax.set_ylabel(r"$\Delta$ Escape Step", fontsize=14)
ax.tick_params(axis='both', labelsize=16)
if len(covs) > 1:
    r, pval = spearmanr(covs, deltas)
    stat_text = fr"Spearman $\rho = {r:.2f}$" + "\n" + fr"$p = {pval:.3g}$"
    ax.text(0.45, 0.95, stat_text, transform=ax.transAxes,
            fontsize=11, verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_11644\3715157911.py:53: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_obj = cm.get_cmap('tab10')
# C:\Users\maria\AppData\Local\Temp\ipykernel_11644\3715157911.py:57: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_obj = cm.get_cmap('tab10')
# Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.
