# %% [markdown]
# # Time taken to adapt to a cocktail for all antibody combos

# %%
import os
import sys
import torch
from itertools import product
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns
import matplotlib.patches as patches
from matplotlib.patches import Patch
import itertools

from tqdm import tqdm

main_path = "../"

sys.path.append(main_path + "PGM/source/")
sys.path.append(main_path + "PGM/utilities/")
import utilities, Proteins_utils, sequence_logo, plots_utils

os.chdir('../covid')
from global_variables import *
from utils_evaluate_seq import *
os.chdir('../mean_field_theory')
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Out:
# e:\ESCAPE_PATHS\mean_field_theory\../PGM/source\numba_utilities.py:1124: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float32, 2, 'F', False, aligned=True), Array(float32, 2, 'A', False, aligned=True))
#   dmean_v_dw = np.dot(s1.T, V)
# e:\ESCAPE_PATHS\mean_field_theory\../PGM/source\numba_utilities.py:961: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float32, 1, 'A', False, aligned=True), Array(float32, 2, 'A', False, aligned=True))
#   mean_V = np.dot(weights, V) / sum_weights
# Loaded 29 KD vectors
# C:\Users\maria\AppData\Roaming\Python\Python312\site-packages\Bio\pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %% [markdown]
# # Read results

# %%
PROT_INIT = Proteins_utils.load_FASTA("../covid/exp_data/wt_omicron.fasta")[0]
PROT_INIT = PROT_INIT[BEGIN:-END]

# %%
L=PROT_INIT.shape[0]
Q = 20

# %% [markdown]
# # AA proba per step, generative function method

# %% [markdown]
# ## Compute

# %%
D=1
BETA_AB=1

# %% [markdown]
# # Escape

# %%
ab_names= list(ESCAPE_VECTORS.keys())
ab_focused = ["REGN10933", "REGN10987",'LY-CoV555','LY-CoV016']
indexes_abs = [ab_names.index(ab) for ab in ab_focused]
ab_names
# Out:
# ['COV2-2050',
#  'COV2-2082',
#  'COV2-2094',
#  'COV2-2096',
#  'COV2-2130',
#  'COV2-2165',
#  'COV2-2196',
#  'COV2-2479',
#  'COV2-2499',
#  'COV2-2677',
#  'COV2-2832',
#  'CR3022',
#  'LY-CoV016',
#  'LY-CoV555',
#  'REGN10933',
#  'REGN10987',
#  'S2D106',
#  'S2E12',
#  'S2H13',
#  'S2H14',
#  'S2H58',
#  'S2H97',
#  'S2X16',
#  'S2X227',
#  'S2X259',
#  'S2X35',
#  'S2X58',
#  'S304',
#  'S309']

# %% [markdown]
# # Order params

# %%
dir = 'results_scripts/all_cocktails'

def extract_parameters(path):
    beta_ab_match = re.search(r'beta_ab_(\d+(?:\.\d+)?)', path)
    D_match = re.search(r'D_(\d+)', path)
    ab_parts = path.split('ab_')
    condition = ab_parts[3] if len(ab_parts) > 3 else None
    return {
        "beta_ab": float(beta_ab_match.group(1)) if beta_ab_match else None,
        "D": int(D_match.group(1)) if D_match else None,
        "condition": condition
    }

# %% [markdown]
# # all cocktails with REGN 10933

# %%
all_dirs = [d for d in os.listdir(dir) if os.path.isdir(os.path.join(dir, d))]

# Initialize lists
all_paths = []
# labels = []


for d in all_dirs:
    params = extract_parameters(d)
    if (
        params["beta_ab"] == BETA_AB and
        params["D"] == D 
    ):
        all_paths.append(d)
        # labels.append(d)


def get_escape_step(filepath, ab_indices, L):
    """Compute escape step where fitness crosses 0.5"""
    mopt = np.exp(np.load(filepath+'/mopt.npy')[:, :] )
    fitness = np.prod(1 - mopt[:, ab_indices], axis=1)
    escape_step = np.argmax(fitness > 0.5) if np.any(fitness > 0.5) else len(fitness)
    return escape_step

def compute_delta_escape_steps(all_dir, ab_names, L):
    results = {}

    for fname in os.listdir(all_dir):
        if not fname.startswith(f"mean_f_free_ab_beta_ab_{BETA_AB}_D_{D}_ab_"):
            print('skipping', fname)
            continue
     

        ab_part = fname.split("ab_")[3]
        abs_involved = ab_part.split("_")
        abs_involved = [ab for ab in abs_involved if ab in ab_names]

        if len(abs_involved) < 2:
            continue  # skip single-Ab files

        cocktail_path = os.path.join(dir, fname)
        cocktail_indices = [ab_names.index(ab) for ab in abs_involved]
        cocktail_escape = get_escape_step(cocktail_path, cocktail_indices, L)

       
            # Only compute delta if all files found
        results[fname] = cocktail_escape
        

    return results
cocktail_steps = compute_delta_escape_steps(dir, ab_names, L)
cocktail_steps
# Out:
# {'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2082': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2094': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2096': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2130': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2165': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2196': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2050_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2094': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2096': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2130': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2165': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2196': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2082_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2096': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2130': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2165': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2196': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2094_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2130': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2165': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2196': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2096_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2165': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2196': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_LY-CoV016': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_LY-CoV555': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_REGN10933': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_REGN10987': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2E12': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H13': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H14': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X16': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S2X58': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S304': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2130_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2196': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2165_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2479': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2499': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_LY-CoV016': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_LY-CoV555': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_REGN10933': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_REGN10987': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2E12': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H13': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H14': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H58': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X16': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X227': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X35': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S2X58': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S304': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2196_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_COV2-2499': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2479_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_COV2-2677': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_LY-CoV016': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_REGN10987': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2E12': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H13': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H14': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X16': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S2X58': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S304': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2499_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_COV2-2832': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2677_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_CR3022': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_COV2-2832_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_LY-CoV016': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_LY-CoV555': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_REGN10933': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_REGN10987': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_CR3022_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_LY-CoV555': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_REGN10933': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_REGN10987': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2D106': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2E12': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H13': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H14': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H58': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X16': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X227': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X35': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S2X58': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S304': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV016_S309': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_REGN10933': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_REGN10987': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2E12': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H13': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H14': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H58': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X16': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S2X58': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S304': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_LY-CoV555_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_REGN10987': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2E12': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H13': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H14': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H58': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X16': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S2X58': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S304': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10933_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2D106': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2E12': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H13': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H14': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H58': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X16': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X227': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X35': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S2X58': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S304': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_REGN10987_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2E12': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H13': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H14': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2D106_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H13': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H14': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H58': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X16': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X227': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X35': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S2X58': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S304': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2E12_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2H14': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2H58': 7,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X16': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X227': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X35': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S2X58': 2,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S304': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H13_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2H58': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X16': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X227': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X35': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S2X58': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S304': 5,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H14_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2H97': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X16': 6,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S2X58': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S304': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H58_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X16': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X227': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2H97_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X227': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X35': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S2X58': 3,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S304': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X16_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S2X259': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S2X58': 8,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X227_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S2X35': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S2X58': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X259_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X35_S2X58': 9,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X35_S304': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X35_S309': 11,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X58_S304': 4,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S2X58_S309': 10,
#  'mean_f_free_ab_beta_ab_1_D_1_ab_S304_S309': 11}

# %%
ab_class_df_mapping=pd.read_csv('../covid/exp_data/bloom_ab_classification/ab_classification.csv')
class_mapping = ab_class_df_mapping.set_index('condition')['condition_subtype'].to_dict()#condition is antibody name, condition_subtype is class
#add VIR-7229: class 1 and SA44: class 4
class_mapping['VIR-7229'] = 'class 1'
class_mapping['SA55'] = 'class 4'
ab_names=list(ESCAPE_VECTORS.keys())#ab_names#name of antibodies
#create a dataframe conaining name of antibodies and their class obtained from the mapping
ab_class_df=pd.DataFrame({'antibody':ab_names})
ab_class_df['class'] = ab_class_df['antibody'].map(class_mapping)
ab_class_df
# Out:
#      antibody    class
# 0   COV2-2050  class 2
# 1   COV2-2082  class 4
# 2   COV2-2094  class 4
# 3   COV2-2096  class 2
# 4   COV2-2130  class 3
# 5   COV2-2165  class 1
# 6   COV2-2196  class 1
# 7   COV2-2479  class 2
# 8   COV2-2499  class 3
# 9   COV2-2677  class 4
# 10  COV2-2832  class 1
# 11     CR3022  class 4
# 12  LY-CoV016  class 1
# 13  LY-CoV555  class 2
# 14  REGN10933  class 1
# 15  REGN10987  class 3
# 16     S2D106  class 2
# 17      S2E12  class 1
# 18      S2H13  class 2
# 19      S2H14  class 1
# 20      S2H58  class 2
# 21      S2H97  class 4
# 22      S2X16  class 2
# 23     S2X227  class 3
# 24     S2X259  class 4
# 25      S2X35  class 4
# 26      S2X58  class 2
# 27       S304  class 4
# 28       S309  class 3

# %%
# -------- 1) Antibody classes + ordering (same as before) --------
ab_class_df = pd.DataFrame({'antibody': ab_names})
ab_class_df['class'] = ab_class_df['antibody'].map(class_mapping).fillna('Unknown')

# sensible class order: class 1..class 5, then others, then Unknown
classes_present = list(pd.unique(ab_class_df['class']))
base_order = [f'class {i}' for i in range(1, 6)]
known = [c for c in base_order if c in classes_present]
others = [c for c in classes_present if c not in known and c != 'Unknown']
final_order = known + sorted(others) + (['Unknown'] if 'Unknown' in classes_present else [])

ab_class_df['class'] = pd.Categorical(ab_class_df['class'], categories=final_order, ordered=True)
ab_class_df_sorted = ab_class_df.sort_values(['class', 'antibody'])
sorted_ab_names = ab_class_df_sorted['antibody'].tolist()

# class -> color mapping (same palette usage as before)
class_colors = ab_class_df_sorted['class'].drop_duplicates().reset_index(drop=True)
color_map = {k: f"C{i}" for i, k in enumerate(class_colors)}

# -------- 2) Parse pairwise escape steps from cocktail_steps --------
# Keys look like: "..._ab_<Ab1>_<Ab2>"
pair_steps = {}
pattern = re.compile(r'_ab_([^_]+)_([^_]+)$')

for k, v in cocktail_steps.items():
    m = pattern.search(k)
    if not m:
        continue
    a, b = m.group(1), m.group(2)
    # keep only pairs that exist in our ab list
    if a in ab_names and b in ab_names:
        pair_steps[(a, b)] = v
        pair_steps[(b, a)] = v  # mirror to ease filling

# -------- 3) Build steps matrix in class-sorted order --------
steps_matrix = pd.DataFrame(np.nan, index=sorted_ab_names, columns=sorted_ab_names, dtype=float)
for (a, b), val in pair_steps.items():
    if a in steps_matrix.index and b in steps_matrix.columns:
        steps_matrix.at[a, b] = val

# lower-triangle display only (+ white diagonal)
np.fill_diagonal(steps_matrix.values, np.nan)
mask = np.triu(np.ones_like(steps_matrix, dtype=bool), k=1)

# -------- 4) Plot --------
plt.figure(figsize=(6.5, 6), dpi=300)

# use a sequential cmap (steps are non-negative); keep NaNs white
cmap = plt.get_cmap('YlOrRd').copy()
cmap.set_bad(color='white')

vmax = np.nanmax(steps_matrix.values)
ax = sns.heatmap(
    steps_matrix,
    cmap=cmap,
    vmin=0,
    vmax=vmax if np.isfinite(vmax) else None,
    mask=mask,
    xticklabels=sorted_ab_names,
    yticklabels=sorted_ab_names,
    cbar_kws={'label': 'Escape steps'}
)

# color axis tick labels by class; optional bold for highlights
highlight_abs = set()  # e.g., {"S2E12", "REGN10933", "REGN10987"}
xticks = ax.get_xticklabels()
yticks = ax.get_yticklabels()

for i, tick in enumerate(xticks):
    ab = ab_class_df_sorted.iloc[i]['antibody']
    tick.set_color(color_map[ab_class_df_sorted.iloc[i]['class']])
    if ab in highlight_abs:
        tick.set_fontweight('bold')

for i, tick in enumerate(yticks):
    ab = ab_class_df_sorted.iloc[i]['antibody']
    tick.set_color(color_map[ab_class_df_sorted.iloc[i]['class']])
    if ab in highlight_abs:
        tick.set_fontweight('bold')

ax.set_xticklabels(xticks, rotation=45, ha='right', fontsize=8)
ax.set_yticklabels(yticks, rotation=0, ha='right', fontsize=8)

# class legend (same colors as labels)
legend_elements = [
    Patch(facecolor=color_map[c], edgecolor='black', label=str(c))
    for c in class_colors
]
ax.legend(
    handles=legend_elements,
    title="Antibody Class",
    bbox_to_anchor=(0.35, 0.95),
    loc='upper left',
    borderaxespad=0.,
    fontsize=12,
    title_fontsize=12
)

# thin black frame around matrix
n = len(sorted_ab_names)
rect = patches.Rectangle(
    (0, 0), n, n,
    linewidth=0.5, edgecolor='black', facecolor='none', clip_on=False
)
ax.add_patch(rect)

plt.tight_layout()
plt.show()

# %%
abs_set = set(ab_names)
pair_re = re.compile(r'_ab_([^_]+)_([^_]+)$')

present = set()
unknown_key_refs = []

for k in cocktail_steps:
    m = pair_re.search(k)
    if not m:
        continue
    a, b = m.group(1), m.group(2)
    if a in abs_set and b in abs_set and a != b:
        present.add(frozenset((a, b)))
    else:
        unknown_key_refs.append((k, a, b))

expected = {frozenset(p) for p in itertools.combinations(sorted(abs_set), 2)}
missing = sorted((tuple(sorted(fs)) for fs in (expected - present)), key=lambda x: (x[0], x[1]))

print(f"Total pairs expected: {len(expected)}")
print(f"Pairs present: {len(present)}")
print(f"Missing pairs: {len(missing)}")

for a, b in missing:
    print(f"{a}, {b}")

# Optional: report keys that reference antibodies not in ab_names
if unknown_key_refs:
    print("\nKeys referencing antibodies not in ab_names:")
    for k, a, b in unknown_key_refs:
        print(f"{k}  ->  ({a}, {b})")
# Out:
# Total pairs expected: 406
# Pairs present: 406
# Missing pairs: 0

# %% [markdown]
# ## Delta escape cocktail vs single ab, compared to corr wighted by MSA

# %%
msa_seqs=Proteins_utils.load_FASTA('../covid/RBM_artif_seq.fasta')
msa_seqs.shape
# Out:
# (1000, 178)

# %%
escapes = np.array([get_log_bindings(msa_seqs[i]) for i in range(msa_seqs.shape[0])])
escapes.shape  #1000*29 as wqe have 29 abs
# Out:
# (1000, 29)

# %%
# 1) Classes + ordering consistent with your previous plot
ab_class_df = pd.DataFrame({'antibody': ab_names})
ab_class_df['class'] = ab_class_df['antibody'].map(class_mapping).fillna('Unknown')

base_order = [f'class {i}' for i in range(1, 6)]
present = list(pd.unique(ab_class_df['class']))
known = [c for c in base_order if c in present]
others = [c for c in present if c not in known and c != 'Unknown']
final_order = known + sorted(others) + (['Unknown'] if 'Unknown' in present else [])

ab_class_df['class'] = pd.Categorical(ab_class_df['class'], categories=final_order, ordered=True)
ab_class_df_sorted = ab_class_df.sort_values(['class', 'antibody'])
sorted_ab_names = ab_class_df_sorted['antibody'].tolist()

# class -> color mapping (same pattern as before)
class_colors = ab_class_df_sorted['class'].drop_duplicates().reset_index(drop=True)
color_map = {k: f"C{i}" for i, k in enumerate(class_colors)}

# 2) Covariance matrix between antibodies
df_esc = pd.DataFrame(escapes, columns=ab_names)
cov_matrix = df_esc.cov(min_periods=1)  # pairwise cov; ignores NaNs where needed

# reorder to class-sorted antibodies
sorted_cov = cov_matrix.loc[sorted_ab_names, sorted_ab_names].astype(float)

# 3) Lower triangle only; hide diagonal
np.fill_diagonal(sorted_cov.values, np.nan)
mask = np.triu(np.ones_like(sorted_cov, dtype=bool), k=1)

# 4) Plot
plt.figure(figsize=(6.5, 6), dpi=300)
cmap = plt.get_cmap('RdBu_r').copy()
cmap.set_bad(color='white')  # NaNs (upper triangle + diagonal) show as white

# symmetric color scale around 0
vabs = np.nanmax(np.abs(sorted_cov.values))
vmin, vmax = (-vabs, vabs) if np.isfinite(vabs) else (None, None)

ax = sns.heatmap(
    sorted_cov,
    cmap=cmap,
    # vmin=vmin, vmax=vmax,
    mask=mask,
    xticklabels=sorted_ab_names,
    yticklabels=sorted_ab_names,
    cbar_kws={'label': 'Covariance'},
    vmin=-1.5,
    vmax=1.5
)

# color tick labels by class; optionally bold some antibodies
highlight_abs = set()  # e.g., {"REGN10933", "REGN10987", "S309"}
xticks = ax.get_xticklabels()
yticks = ax.get_yticklabels()

for i, tick in enumerate(xticks):
    ab = ab_class_df_sorted.iloc[i]['antibody']
    tick.set_color(color_map[ab_class_df_sorted.iloc[i]['class']])
    if ab in highlight_abs:
        tick.set_fontweight('bold')

for i, tick in enumerate(yticks):
    ab = ab_class_df_sorted.iloc[i]['antibody']
    tick.set_color(color_map[ab_class_df_sorted.iloc[i]['class']])
    if ab in highlight_abs:
        tick.set_fontweight('bold')

ax.set_xticklabels(xticks, rotation=45, ha='right', fontsize=8)
ax.set_yticklabels(yticks, rotation=0, ha='right', fontsize=8)

# class legend
legend_elements = [
    Patch(facecolor=color_map[c], edgecolor='black', label=str(c))
    for c in class_colors
]
ax.legend(
    handles=legend_elements,
    title="Antibody Class",
    bbox_to_anchor=(0.35, 0.95),
    loc='upper left',
    borderaxespad=0.,
    fontsize=12,
    title_fontsize=12
)

# thin black frame around the matrix
n = len(sorted_ab_names)
rect = patches.Rectangle((0, 0), n, n, linewidth=0.5, edgecolor='black',
                         facecolor='none', clip_on=False)
ax.add_patch(rect)

plt.tight_layout()
plt.show()
